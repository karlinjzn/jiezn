# %%
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates
import pylab
from pylab import * 
import time
import datetime
% matplotlib inline
# -*- coding:utf-8 -*-

# %%
data_1 = pd.read_csv('RFID_945132210288380921.csv', encoding='gbk')
data_2 = pd.read_excel('snsr_20171222-20171223.xlsx', sheetname=0)

# %%
print len(data_1)
print len(data_2)
data_1 = data_1.dropna(thresh = 4)
data_2 = data_2.dropna(thresh = 3)

data_1 = data_1.replace([u'进入',u'离开'], [1,0])
data_2 = data_2.replace([u'进入',u'离开'], [1,0])

print len(data_1)
print len(data_2)
print len(set(data_1['locationId']))
print len(set(data_1['tagId']))
print len(set(data_2[u'地点']))
# Out:
# 11866
# 10551
# 11806
# 10551
# 5
# 18
# 7

# %%
data1 = data_1[8790:]
data1
# Out:
#                           tagId       locationId  eventType transactionTime  \
# 8850   E280110C2000758C875B08DF       LINE1#01_A          1        18:57:10
# 8851   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8852   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8853   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8854   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8855   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8856   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8857   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8858   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8859   E280110C2000758C875B08DF       LINE1#01_A          0        18:57:14
# 8860   E280110C2000758C875B08DF       LINE1#01_A          1        18:57:14
# ...

# %%
data2 = data_2[10427:]
data2
# Out:
#                地点  事件类型                  时间  备注
# 10427  LINE1#04_A     1 2017-12-22 18:57:36 NaN
# 10428  LINE1#04_A     0 2017-12-22 18:57:36 NaN
# 10429  LINE1#04_A     1 2017-12-22 18:57:36 NaN
# 10430  LINE1#04_A     0 2017-12-22 18:57:36 NaN
# 10431  LINE1#04_A     1 2017-12-22 18:57:36 NaN
# 10432  LINE1#04_A     0 2017-12-22 18:57:36 NaN
# 10433  LINE1#04_A     1 2017-12-22 18:58:16 NaN
# 10434  LINE1#04_A     0 2017-12-22 18:58:16 NaN
# 10435  LINE1#06_A     1 2017-12-22 18:58:17 NaN
# 10436  LINE1#06_A     0 2017-12-22 18:58:18 NaN
# 10437  LINE1#01_A     1 2017-12-22 18:58:51 NaN
# 10438  LINE1#01_A     0 2017-12-22 18:58:52 NaN
# 10439  LINE1#04_A     1 2017-12-22 18:58:58 NaN
# 10440  LINE1#04_A     0 2017-12-22 18:58:59 NaN
# 10441  LINE1#06_A     1 2017-12-22 18:59:01 NaN
# 10442  LINE1#06_A     0 2017-12-22 18:59:02 NaN
# 10443  LINE1#06_A     1 2017-12-22 18:59:03 NaN
# 10444  LINE1#06_A     0 2017-12-22 18:59:03 NaN
# 10445  LINE1#04_A     1 2017-12-22 18:59:35 NaN
# ...

# %%
data_2.columns
# Out:
# Index([u'地点', u'事件类型', u'时间', u'备注'], dtype='object')

# %%
x.remove((u'E280110C2000744C876808DF', u'LINE1#01_A'))
x.remove((u'E280110C2000744C876808DF', u'LINE1#04_D_#05A'),(u'E280110C2000770B876808DF', u'LINE1#01_D_#02A'),
 (u'E280110C2000770B876808DF', u'LINE1#02_D_#03A'),
 (u'E280110C2000770B876808DF', u'LINE1#03_D_#04A'),
 (u'E280110C2000778C875B08DF', u'LINE1#01_D_#02A'),
 (u'E280110C2000778C875B08DF', u'LINE1#03_D_#04A'),
 (u'E280110C2000778C875B08DF', u'LINE1#04_D_#05A'),)

# %%
group = list(set(grouped1.groups))[31]
print grouped1.get_group(group)['transactionTime']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-918ff52754a9> in <module>()
# ----> 1 group = list(set(grouped1.groups))[31]
#       2 print grouped1.get_group(group)['transactionTime']
#
# IndexError: list index out of range

# %%
group = list(set(grouped1.groups))[18]
print grouped1.get_group(group)['transactionTime']
# Out:
# 9283     18:58:54
# 9284     18:58:54
# 9285     18:58:54
# 9286     18:58:54
# 9287     18:58:54
# 9288     18:58:54
# 9289     18:58:54
# 9290     18:58:54
# 9291     18:58:54
# 9319     18:58:59
# 9320     18:58:59
# 9321     18:58:59
# 9322     18:58:59
# 9323     18:58:59
# 9324     18:58:59
# 9325     18:58:59
# 9326     18:58:59
# 9327     18:58:59
# 9328     18:58:59
# 9329     18:58:59
# 9330     18:58:59
# 9331     18:58:59
# 9332     18:58:59
# 9333     18:58:59
# 9334     18:58:59
# 9335     18:58:59
# 9336     18:58:59
# 9355     18:59:03
# 9356     18:59:03
# 9357     18:59:03
#            ...
# 9496     18:59:27
# 9497     18:59:27
# 9498     18:59:27
# 9499     18:59:31
# 9500     18:59:31
# 9501     18:59:31
# 9502     18:59:31
# 9503     18:59:31
# 9504     18:59:31
# 9505     18:59:31
# 9506     18:59:31
# 9507     18:59:31
# 11038    19:05:24
# 11039    19:05:24
# 11040    19:05:24
# 11041    19:05:24
# 11042    19:05:24
# 11043    19:05:24
# 11044    19:05:24
# ...

# %%
ids = []
for i in list(set(grouped1.groups)):
    ids.append(i[0])
#ids = list(set(ids))
print ids
# Out:
# [u'E280110C2000778C875B08DF', u'E280110C2000790C877C08DF', u'E280110C2000778C875B08DF', u'E280110C20007ACC876F08DF', u'E280110C2000790C877C08DF', u'E280110C2000770B876808DF', u'E280110C2000724C876508DF', u'E280110C2000754C875B08DF', u'E280110C2000770B876808DF', u'E280110C2000724C876508DF', u'E280110C2000770B876808DF', u'E280110C200070CC877308DF', u'E280110C2000758C875B08DF', u'E280110C2000754C875B08DF', u'E280110C2000744C876808DF', u'E280110C2000778C875B08DF', u'E280110C20007ACC876F08DF', u'E280110C2000790C877C08DF', u'E280110C2000758C875B08DF', u'E280110C2000724C876508DF', u'E280110C20007ACC876F08DF', u'E280110C2000790C877C08DF', u'E280110C2000754C875B08DF', u'E280110C2000758C875B08DF', u'E280110C200070CC877308DF', u'E280110C2000724C876508DF', u'E280110C2000744C876808DF', u'E280110C2000754C875B08DF', u'E280110C2000758C875B08DF', u'E280110C200070CC877308DF', u'E280110C200070CC877308DF']

# %%
ids[0]
# Out:
# u'E280110C2000724C876508DF'

# %%
list(set(grouped1.groups))[0][0]
# Out:
# u'E280110C2000778C875B08DF'

# %%
t = []
#flag = 0
#print grouped1.get_group(('E280110C200070CC877308DF','LINE1#01_A'))['transactionTime'][9832]
for group in set(grouped1.groups):
    for i in grouped1.get_group(group)['transactionTime']:
        t.append(i)
        break

# %%
print t
# Out:
# [u'19:07:01', u'19:00:48', u'19:04:26', u'18:59:37', u'19:04:08', u'19:00:25', u'18:57:36', u'19:02:16', u'18:58:57', u'18:58:57', u'19:00:30', u'19:05:05', u'19:04:05', u'19:05:53', u'18:59:55', u'19:06:28', u'19:00:28', u'18:59:18', u'18:58:54', u'19:00:25', u'18:58:48', u'19:01:30', u'19:03:29', u'18:57:10', u'19:00:50', u'18:58:17', u'19:03:22', u'19:06:29', u'19:05:51', u'19:03:19', u'19:04:07']

# %%
tnew = [[u'19:07:01', u'19:00:48', u'19:04:26', u'18:59:37'],
        [u'19:04:08', u'19:00:25', u'18:57:36', u'19:02:16'],
        [u'18:58:57', u'18:58:57'],
        [u'19:00:30', u'19:05:05', u'19:04:05', u'19:05:53'],
        [u'18:59:55', u'19:06:28', u'19:00:28', u'18:59:18'],
        [u'18:58:54', u'19:00:25', u'18:58:48'],
        [u'19:01:30', u'19:03:29', u'18:57:10'],
        [u'19:00:50', u'18:58:17', u'19:03:22', u'19:06:29'],
        [u'19:05:51', u'19:03:19', u'19:04:07']]

# %%
grouped1 = data1.groupby(['tagId','locationId'])
len(grouped1.groups)
x = set(grouped1.groups)
set(grouped1.groups)
# Out:
# {(u'E280110C200070CC877308DF', u'LINE1#01_A'),
#  (u'E280110C200070CC877308DF', u'LINE1#02_D_#03A'),
#  (u'E280110C200070CC877308DF', u'LINE1#03_D_#04A'),
#  (u'E280110C200070CC877308DF', u'LINE1#04_D_#05A'),
#  (u'E280110C2000724C876508DF', u'LINE1#01_A'),
#  (u'E280110C2000724C876508DF', u'LINE1#01_D_#02A'),
#  (u'E280110C2000724C876508DF', u'LINE1#02_D_#03A'),
#  (u'E280110C2000724C876508DF', u'LINE1#04_D_#05A'),
#  (u'E280110C2000744C876808DF', u'LINE1#01_A'),
#  (u'E280110C2000744C876808DF', u'LINE1#04_D_#05A'),
#  (u'E280110C2000754C875B08DF', u'LINE1#01_A'),
#  (u'E280110C2000754C875B08DF', u'LINE1#01_D_#02A'),
#  (u'E280110C2000754C875B08DF', u'LINE1#03_D_#04A'),
#  (u'E280110C2000754C875B08DF', u'LINE1#04_D_#05A'),
#  (u'E280110C2000758C875B08DF', u'LINE1#01_A'),
#  (u'E280110C2000758C875B08DF', u'LINE1#02_D_#03A'),
#  (u'E280110C2000758C875B08DF', u'LINE1#03_D_#04A'),
#  (u'E280110C2000758C875B08DF', u'LINE1#04_D_#05A'),
# ...

# %%
cc = [155,
112,
48,
360,
187]
var(cc)
# Out:
# 10966.639999999998

# %%
t = []
flag = 0
#print grouped1.get_group(('E280110C200070CC877308DF','LINE1#01_A'))['transactionTime'][9832]
for group in list(set(grouped1.groups)):
    tmp = []
    if group[0] == ids[flag]:
        for i in grouped1.get_group(group)['transactionTime']:
            tmp.append(i)
            break
    else:
        t.append(tmp)
        flag += 1
        tmp = []
        for i in grouped1.get_group(group)['transactionTime']:
            tmp.append(i)
            break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-98a4a4894302> in <module>()
#       4 for group in list(set(grouped1.groups)):
#       5     tmp = []
# ----> 6     if group[0] == ids[flag]:
#       7         for i in grouped1.get_group(group)['transactionTime']:
#       8             tmp.append(i)
#
# IndexError: list index out of range

# %%
grouped2 = data1.groupby(['locationId'])
len(grouped2.groups)
# Out:
# 5

# %%
set(grouped3.groups)
# Out:
# {u'LINE1#01_A', u'LINE1#02_A', u'LINE1#04_A', u'LINE1#05_A', u'LINE1#06_A'}

# %%
grouped3 = data2.groupby([u'地点'])
len(grouped3.groups)
# Out:
# 5

# %%
set(grouped3.groups)
# Out:
# {u'LINE1#01_A', u'LINE1#02_A', u'LINE1#04_A', u'LINE1#05_A', u'LINE1#06_A'}

# %%
grouped3.get_group('LINE1#06_A')[u'时间']
# Out:
# 10435   2017-12-22 18:58:17
# 10436   2017-12-22 18:58:18
# 10441   2017-12-22 18:59:01
# 10442   2017-12-22 18:59:02
# 10443   2017-12-22 18:59:03
# 10444   2017-12-22 18:59:03
# 10453   2017-12-22 18:59:51
# 10454   2017-12-22 18:59:52
# 10457   2017-12-22 19:00:32
# 10458   2017-12-22 19:00:33
# 10483   2017-12-22 19:01:56
# 10484   2017-12-22 19:01:56
# 10491   2017-12-22 19:02:30
# 10492   2017-12-22 19:02:31
# 10513   2017-12-22 19:03:25
# 10514   2017-12-22 19:03:26
# 10521   2017-12-22 19:04:07
# 10522   2017-12-22 19:04:08
# 10523   2017-12-22 19:04:08
# 10530   2017-12-22 19:04:56
# 10531   2017-12-22 19:04:56
# 10532   2017-12-22 19:04:57
# 10537   2017-12-22 19:05:26
# 10538   2017-12-22 19:05:27
# Name: 时间, dtype: datetime64[ns]

# %%
plt.figure(figsize=(16,9))
#t2 = [datetime.strptime(d, '%Y-%m-%d %H:%M:%S.%f').date() for d in t]

#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y %H:%M:%S'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

#x = grouped3.get_group('LINE1#01_A')['transactionTime']
y = grouped3.get_group('LINE1#01_A')[u'事件类型']

plt.plot(range(0,len(y)),y,alpha=0.4,marker='o')
#plt.gcf().autofmt_xdate()  # 自动旋转日期标记
plt.show()

# %%
x = grouped2.get_group('LINE1#04_D_#05A')

# %%
grouped2.get_group('LINE1#04_D_#05A')
# Out:
#                           tagId       locationId  eventType transactionTime  \
# 9679   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9680   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9681   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9682   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9683   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9684   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9685   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9686   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9687   E280110C2000724C876508DF  LINE1#04_D_#05A          1        19:00:25
# 9704   E280110C2000724C876508DF  LINE1#04_D_#05A          0        19:00:30
# 9705   E280110C2000724C876508DF  LINE1#04_D_#05A          0        19:00:30
# ...

# %%
x1 = [4, 4, 4, 4, 4, 2, 4, 4, 4, 1, 3, 4, 1, 3, 1, 3, 1, 3]
x2 = [1, 3, 1, 3, 1, 3, 1, 4, 4, 4]
x3 = [5, 2, 4, 4, 4, 4, 1, 3, 4, 4, 4, 4, 1, 3, 1, 3, 6, 4, 1, 3, 1, 4, 4, 4, 4, 4, 4]
x4 = [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 3, 4, 4, 4, 4, 1, 5, 1, 3, 4, 4, 1, 3, 1, 3, 4, 1, 3, 4, 4, 1, 3, 1, 3, 1, 4, 4, 4]
x5 = [5, 3, 3, 5, 5, 3, 2, 5, 4, 4, 4, 3, 1, 3, 4, 1, 3, 1, 3, 4, 1, 3, 1, 3, 1, 3, 11, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 1, 3, 4, 1, 3, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 3, 1, 3, 4]

# %%
x1 = [4, 4, 4, 4, 4, 2, 4, 4, 4, 1, 3, 4, 1, 3, 1, 3, 1, 3]
x2 = [1, 3, 1, 3, 1, 3, 1, 4, 4, 4]
x3 = [84, 5, 2, 58, 4, 105, 4, 4, 4, 1, 3, 4, 4, 4, 4, 1, 3, 1, 3, 6, 4, 1, 3, 1, 4, 4, 4, 4, 4, 4]
x4 = [4, 4, 4, 4, 4, 4, 4, 4, 59, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 3, 4, 153, 4, 73, 4, 25, 4, 1, 5, 1, 3, 4, 4, 1, 3, 1, 3, 4, 1, 3, 4, 4, 1, 3, 1, 3, 1, 4, 4, 4]
x5 = [172, 5, 3, 3, 5, 5, 25, 3, 2, 5, 4, 4, 4, 35, 3, 1, 3, 4, 1, 3, 1, 3, 4, 1, 3, 1, 3, 1, 3, 11, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 1, 3, 4, 1, 3, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 3, 1, 3, 4]

# %%
a = []
for i in x1:
    print i
    if i<= 20:
        a.append(i) 
    
b = []
for i in x2:
    if i<= 20:
        b.append(i) 
        
c = []
for i in x3:
    if i<= 20:
        c.append(i) 
        
d = []
for i in x4:
    if i<= 20:
        d.append(i) 
        
e = []
for i in x5:
    if i<= 20:
        e.append(i)
# Out:
# 4
# 4
# 4
# 4
# 4
# 2
# 4
# 4
# 4
# 1
# 3
# 4
# 1
# 3
# 1
# 3
# 1
# 3

# %%
print mean(a)
print mean(b)
print mean(c)
print mean(d)
print mean(e)
# Out:
# 3.0
# 2.5
# 3.33333333333
# 3.35294117647
# 3.31034482759

# %%
print var(a)
print var(b)
print var(c)
print var(d)
print var(e)
# Out:
# 1.44444444444
# 1.65
# 1.7037037037
# 1.32641291811
# 2.52437574316

# %%
plt.figure(figsize=(16,9))
plt.plot(a,alpha=0.4,marker='o',label='position 1')
plt.plot(b,alpha=0.4,marker='o',label='position 2')
plt.plot(c,alpha=0.4,marker='o',label='position 3')
plt.plot(d,alpha=0.4,marker='o',label='position 4')
plt.plot(e,alpha=0.4,marker='o',label='position 5')
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)  
plt.show()

# %%
t = []
for j in range(1,len(x.index)):
    i = x.index[j]
    if x['eventType'][i]:
        if x['eventType'][i] == x['eventType'][x.index[j-1]]:
            continue
    t.append(x['transactionTime'][i])

# %%
a = time.strptime(t[1],"%H:%M:%S")
b = time.strptime(t[2],"%H:%M:%S")
datetime.datetime(*a[:6])
# Out:
# datetime.datetime(1900, 1, 1, 18, 57, 14)

# %%
print (datetime.datetime(*b[:6])-datetime.datetime(*a[:6])).seconds
# Out:
# 4

# %%
inte = []
for i in range(1,len(t)):
    a = time.strptime(t[i-1],"%H:%M:%S")
    b = time.strptime(t[i],"%H:%M:%S")
    inte.append((datetime.datetime(*b[:6])-datetime.datetime(*a[:6])).seconds)

# %%
result = []
for i in inte:
    if i != 0:
        result.append(i)
print result
# Out:
# [172, 5, 3, 3, 5, 5, 25, 3, 2, 5, 4, 4, 4, 35, 3, 1, 3, 4, 1, 3, 1, 3, 4, 1, 3, 1, 3, 1, 3, 11, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 1, 3, 4, 1, 3, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 1, 3, 1, 3, 4]

# %%
startTime= time.strptime("%H:%M:%s", time.localtime())  
endTime= time.strptime("%H:%M:%s", time.localtime())  
startTime= datetime.datetime.strptime(startTime,"%Y-%m-%d %H:%M:%S")  
endTime= datetime.datetime.strptime(endTime,"%Y-%m-%d %H:%M:%S")  
# 相减得到秒数  
seconds = (endTime- startTime).seconds  
hours=(endTime- startTime).hours  
day=(endTime- startTime).day

# %%
eventType = grouped1.get_group('LINE1#04_D_#05A')['locationId']
t = grouped1.get_group('LINE1#04_D_#05A')['eventType']

# %%
t = [d for d in t]

# %%
t
# Out:
# [u'2017-12-21 15:05:36.0',
#  u'2017-12-21 15:05:36.0',
#  u'2017-12-21 15:05:36.0',
#  u'2017-12-21 15:05:39.0',
#  u'2017-12-21 15:05:39.0',
#  u'2017-12-21 15:05:39.0',
#  u'2017-12-21 15:06:14.0',
#  u'2017-12-21 15:06:14.0',
#  u'2017-12-21 15:06:14.0',
#  u'2017-12-21 15:06:18.0',
#  u'2017-12-21 15:06:18.0',
#  u'2017-12-21 15:06:18.0',
#  u'2017-12-21 15:06:55.0',
#  u'2017-12-21 15:06:55.0',
#  u'2017-12-21 15:06:55.0',
#  u'2017-12-21 15:06:59.0',
#  u'2017-12-21 15:06:59.0',
#  u'2017-12-21 15:06:59.0',
#  u'2017-12-21 15:08:49.0',
#  u'2017-12-21 15:08:49.0',
#  u'2017-12-21 15:08:49.0',
#  u'2017-12-21 15:08:53.0',
#  u'2017-12-21 15:08:53.0',
#  u'2017-12-21 15:08:53.0',
#  u'2017-12-21 15:13:53.0',
#  u'2017-12-21 15:13:53.0',
#  u'2017-12-21 15:13:53.0',
#  u'2017-12-21 15:13:57.0',
#  u'2017-12-21 15:13:57.0',
#  u'2017-12-21 15:13:57.0',
#  u'2017-12-21 15:14:14.0',
#  u'2017-12-21 15:14:14.0',
#  u'2017-12-21 15:14:14.0',
#  u'2017-12-21 15:14:19.0',
# ...

# %%
pylab.plot_date(pylab.date2num(t), eventType, linestyle='-')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-a31753b8d216> in <module>()
# ----> 1 pylab.plot_date(pylab.date2num(t), eventType, linestyle='-')
#
# /Users/zhuonijie/anaconda2/lib/python2.7/site-packages/matplotlib/dates.pyc in date2num(d)
#     378         if not d.size:
#     379             return d
# --> 380         return _to_ordinalf_np_vectorized(d)
#     381
#     382
#
# /Users/zhuonijie/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.pyc in __call__(self, *args, **kwargs)
#    2737             vargs.extend([kwargs[_n] for _n in names])
#    2738
# -> 2739         return self._vectorize_call(func=func, args=vargs)
#    2740
#    2741     def _get_ufunc_and_otypes(self, func, args):
#
# /Users/zhuonijie/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.pyc in _vectorize_call(self, func, args)
# ...

# %%
eventType = [d for d in eventType]

# %%
plt.figure(figsize=(16,9))
#t2 = [datetime.strptime(d, '%Y-%m-%d %H:%M:%S.%f').date() for d in t]

#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y %H:%M:%S'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())

x = t2[500:1000]
y = eventType[500:1000]

plt.plot(eventType[-100:],alpha=0.4,marker='o')
plt.gcf().autofmt_xdate()  # 自动旋转日期标记
plt.show()

# %%
data = pd.read_excel('mat_rfid_ev.xlsx', sheetname=0)

# %%
data2 = pd.read_excel('mat_snsr_ev.xlsx', sheetname=0)

# %%
data
# Out:
#         dbid  obj_ver  mat_bzid                    tag_id           loc_id  \
# 0       2436        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# 1       2437        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# 2       2438        0       NaN  E280110C200076CC877608DF  LINE1#01_D_#02A
# 3       2439        0       NaN  E280110C200076CC877608DF  LINE1#01_D_#02A
# 4       2440        0       NaN  E280110C200076CC877608DF  LINE1#02_D_#03A
# 5       2441        0       NaN  E280110C200076CC877608DF  LINE1#02_D_#03A
# 66      2502        0       NaN  E280110C2000790C877C08DF       LINE1#01_A
# 67      2503        0       NaN  E280110C2000790C877C08DF       LINE1#01_A
# 68      2504        0       NaN  E280110C2000790C877C08DF       LINE1#01_A
# 69      2505        0       NaN  E280110C2000790C877C08DF       LINE1#01_A
# 70      2506        0       NaN  E280110C2000790C877C08DF       LINE1#01_A
# ...

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(data)
com=pca.components_ #返回模型的各个特征向量
pca=pca.explained_variance_ratio_ #返回各个成分各自的方差百分比
print com,"百分比：\n",pca
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-34d2a7f2762a> in <module>()
#       2
#       3 pca = PCA()
# ----> 4 pca.fit(data)
#       5 com=pca.components_ #返回模型的各个特征向量
#       6 pca=pca.explained_variance_ratio_ #返回各个成分各自的方差百分比
#
# /Users/zhuonijie/anaconda2/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in fit(self, X, y)
#     222             Returns the instance itself.
#     223         """
# --> 224         self._fit(X)
#     225         return self
#     226
#
# /Users/zhuonijie/anaconda2/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in _fit(self, X)
#     266             requested.
#     267         """
# --> 268         X = check_array(X)
#     269         n_samples, n_features = X.shape
#     270         X = as_float_array(X, copy=self.copy)
#
# ...

# %%
data2
# Out:
#        obj_ver      number   ev_type           trans_time
# 1            0  LINE1#04_A  ADDITION  12/21/2017 13:15:58
# 2            0  LINE1#04_A  DELETION  12/21/2017 13:15:58
# 3            0  LINE1#04_A  ADDITION  12/21/2017 13:15:58
# 4            0  LINE1#04_A  DELETION  12/21/2017 13:15:58
# 5            0  LINE1#04_A  ADDITION  12/21/2017 13:15:59
# 6            0  LINE1#04_A  DELETION  12/21/2017 13:15:59
# 7            0  LINE1#04_A  ADDITION  12/21/2017 13:15:59
# 8            0  LINE1#04_A  DELETION  12/21/2017 13:15:59
# 9            0  LINE1#04_A  ADDITION  12/21/2017 13:16:03
# 10           0  LINE1#04_A  DELETION  12/21/2017 13:16:03
# 11           0  LINE1#04_A  ADDITION  12/21/2017 13:16:04
# 12           0  LINE1#04_A  DELETION  12/21/2017 13:16:04
# 13           0  LINE1#04_A  ADDITION  12/21/2017 13:16:04
# 14           0  LINE1#04_A  DELETION  12/21/2017 13:16:04
# 15           0  LINE1#04_A  ADDITION  12/21/2017 13:16:04
# ...

# %%
data2 = data2.replace(['ADDITION','DELETION'], [1,0])

# %%
print len(data2)
print len(set(data2['number']))
#print len(set(data2['loc_id']))
# Out:
# 27296
# 7

# %%
data2 = data2.dropna(thresh = 4)

# %%
data = data.replace(['ADDITION','DELETION'], [1,0])

# %%
print len(data)
print len(set(data['tag_id']))
print len(set(data['loc_id']))
# Out:
# 38033
# 28
# 7

# %%
data = data.dropna(thresh = 6)

# %%
len(data)
# Out:
# 37973

# %%
len(data.drop_duplicates())
# Out:
# 37973

# %%
grouped1 = data.groupby(['tag_id'])

# %%
grouped1.groups
# Out:
# {u'E280110C200070CC877308DF': [4990,
#   4991,
#   4992,
#   4993,
#   4994,
#   4995,
#   4998,
#   4999,
#   5000,
#   5001,
#   5002,
#   5003,
#   5020,
#   5021,
#   5022,
#   5023,
#   5028,
#   5029,
#   5036,
#   5037,
#   5046,
#   5047,
#   5056,
#   5057,
#   5068,
#   5069,
#   5075,
#   5079,
#   5087,
#   5089,
#   5095,
#   5097,
#   5098,
#   5099,
#   5106,
#   5109,
#   5132,
#   5133,
#   5136,
#   5137,
#   5138,
#   5139,
#   5144,
#   5145,
#   5202,
#   5203,
#   5208,
#   5209,
#   5230,
#   5231,
#   5234,
#   5235,
#   5242,
#   5243,
#   5248,
#   5249,
#   7257,
#   7258,
#   7259,
#   7266,
#   7267,
#   7268,
#   7269,
#   7270,
#   7271,
#   7278,
#   7279,
#   7280,
#   7281,
#   7282,
#   7283,
#   7290,
#   7291,
#   7292,
#   7293,
#   7294,
#   7295,
#   7302,
#   7303,
#   7304,
#   7305,
#   7306,
#   7307,
#   7314,
#   7315,
#   7316,
#   7317,
#   7318,
#   7319,
#   7326,
#   7327,
#   7328,
#   7329,
#   7330,
#   7331,
#   7338,
#   7339,
# ...

# %%
grouped1.get_group('E280110C200076CC877608DF')
# Out:
#         dbid  obj_ver  mat_bzid                    tag_id           loc_id  \
# 0       2436        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# 1       2437        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# 2       2438        0       NaN  E280110C200076CC877608DF  LINE1#01_D_#02A
# 3       2439        0       NaN  E280110C200076CC877608DF  LINE1#01_D_#02A
# 4       2440        0       NaN  E280110C200076CC877608DF  LINE1#02_D_#03A
# 5       2441        0       NaN  E280110C200076CC877608DF  LINE1#02_D_#03A
# 228     2664        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# 229     2665        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# 230     2666        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# 231     2667        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# 232     2668        0       NaN  E280110C200076CC877608DF       LINE1#01_A
# ...

# %%
ev_type = grouped1.get_group('E280110C200076CC877608DF')['ev_type']
t = grouped1.get_group('E280110C200076CC877608DF')['trans_time']

# %%
plt.plot(ev_type)

# %%
t2 = [datetime.strptime(d, '%m/%d/%Y %H:%M:%S').date() for d in t]

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y %H:%M:%S'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())

# %%
plt.plot(t2,ev_type)
plt.gcf().autofmt_xdate()  # 自动旋转日期标记
plt.show()
